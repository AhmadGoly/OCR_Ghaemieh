# %%
from openai import OpenAI
import base64
from PIL import Image
from io import BytesIO
llm_api_key = "no-key"
llm_url = "http://192.168.159.43:1234/v1"
client = OpenAI(api_key=llm_api_key, base_url=llm_url)
pil_image = Image.open("C:/Users/14032621/Pictures/ketabbb-4-edited.jpg")
buffer = BytesIO()
pil_image.save(buffer, format="JPEG")
img_b64 = base64.b64encode(buffer.getvalue()).decode("utf-8")
data_url = f"data:image/jpeg;base64,{img_b64}"
messages = [
    {
        "role": "system",
        "content": "You are a high-accuracy OCR engine. Output only the extracted text."
    },
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "Read all text in this image. languages might be Persian or English or Arabic"},
            {
                "type": "image_url",
                "image_url": {
                    "url": data_url
                }
            }
        ]
    }
]
response = client.chat.completions.create(
    model="allenai/olmocr-2-7b",
    messages=messages,
    max_tokens=4096
)

text = response.choices[0].message.content
print(text)

# %%
from openai import OpenAI
import base64
from PIL import Image
from io import BytesIO

def olm_ocr_text_extraction(
    pil_image,
    llm_url="http://192.168.159.43:1234/v1",
    llm_api_key="no-key",
    language_list=["fas", "eng"]
):
    client = OpenAI(api_key=llm_api_key, base_url=llm_url)
    
    lang_map = {"fas": "Persian", "eng": "English", "ara": "Arabic"}
    languages = ', '.join([lang_map.get(lang, lang) for lang in language_list])
    
    buffer = BytesIO()
    pil_image.save(buffer, format="JPEG")
    img_b64 = base64.b64encode(buffer.getvalue()).decode("utf-8")
    data_url = f"data:image/jpeg;base64,{img_b64}"
    
    messages = [
        {
            "role": "system",
            "content": "You are a high-accuracy OCR engine. Output only the extracted text."
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": f"Read all text in this image. Languages might be {languages}."},
                {"type": "image_url", "image_url": {"url": data_url}}
            ]
        }
    ]
    
    response = client.chat.completions.create(
        model="allenai/olmocr-2-7b",
        messages=messages,
        max_tokens=4096
    )
    
    return response.choices[0].message.content

# %%
from PIL import Image

image = Image.open("C:/Users/14032621/Pictures/ketabbb-4-edited.jpg")
text = olm_ocr_text_extraction(image)
print(text)
# Out:
# هر روز آدم چیزهای تازهای یاد می‌گیره،
# ولی یه چیز هس که من خوب میدونم،
# وقتی آدم محتاج میشه، یا گرفتاری و
# بدبختی و غمی داره، باید دردشو پیش
# آدمهای ندار بیه. اینها هستن که به آدم
# کمک می‌کنن، فقط اینها.
